# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('Fraction Counts Removed - Sheet1.csv')

# %%
df
# Out:
#     Fraction Removed Organism          Sample
# 0              0.135       MO   Run12_sample1
# 1              0.206       MO   Run12_sample2
# 2              0.198       MO   Run12_sample3
# 3              0.424       MO   Run12_sample5
# 4              0.218       MO   Run12_sample6
# 5              0.178       MO   Run12_sample7
# 6              0.177       MO   Run12_sample9
# 7              0.217       MO  Run12_sample10
# 8              0.257       MO  Run12_sample11
# 9              0.155       MO  Run12_sample12
# 10             0.051       AC   Run12_sample1
# 11             0.055       AC   Run12_sample2
# 12             0.050       AC   Run12_sample3
# 13             0.068       AC   Run12_sample5
# 14             0.062       AC   Run12_sample6
# 15             0.056       AC   Run12_sample7
# 16             0.047       AC   Run12_sample9
# 17             0.061       AC  Run12_sample10
# 18             0.055       AC  Run12_sample11
# 19             0.049       AC  Run12_sample12
# 20             0.032       AC   Run17_sample2
# 21             0.039       AC   Run17_sample3
# 22             0.039       AC   Run17_sample4

# %%
plt.rcParams.update({'font.size': 20})
plt.figure(figsize=(3,10))
sns.boxplot(data = df, x = 'Organism', y = 'Fraction Removed')
plt.ylabel('Fraction of Reads Removed SoupX')
plt.rcParams.update(plt.rcParamsDefault)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2259/1514050553.py in <module>
#       3 sns.boxplot(data = df, x = 'Organism', y = 'Fraction Removed')
#       4 plt.ylabel('Fraction of Reads Removed SoupX')
# ----> 5 plt.ax.set_xticklabels(['Prairie Vole', 'Green Anole'])
#       6 plt.rcParams.update(plt.rcParamsDefault)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'ax'
